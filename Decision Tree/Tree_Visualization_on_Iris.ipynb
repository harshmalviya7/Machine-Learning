# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

iris = load_iris()


tree_clf =DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf=tree_clf.fit(iris.data,iris.target)

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(tree_clf,filled=True)
# Out:
# [Text(334.8, 453.0, 'X[2] <= 2.45\nentropy = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(167.4, 271.8, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(502.20000000000005, 271.8, 'X[3] <= 1.75\nentropy = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(334.8, 90.59999999999997, 'entropy = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(669.6, 90.59999999999997, 'entropy = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %%
print(tree.export_text(tree_clf))
# Out:
# |--- feature_2 <= 2.45
# |   |--- class: 0
# |--- feature_2 >  2.45
# |   |--- feature_3 <= 1.75
# |   |   |--- class: 1
# |   |--- feature_3 >  1.75
# |   |   |--- class: 2
